# %%
import os
list_ = os.listdir('sorted_data/128/Trajectory/')

# %%
for i in range(len(list_)):
    file1 = open('sorted_data/025/Trajectory/' + list_[i], 'r') 
    file = file1.readlines()
    file = file[6:]

# %%
file
# Out:
# ['31.5846599,120.3200183,0,13.1,40005.3822685185,2009-07-11,09:10:28\n',
#  '31.5846649,120.3199183,0,13.1,40005.3822800926,2009-07-11,09:10:29\n',
#  '31.58468,120.3197233,0,6.6,40005.3823032407,2009-07-11,09:10:31\n',
#  '31.5847133,120.3195249,0,0,40005.3823263889,2009-07-11,09:10:33\n',
#  '31.5847932,120.319275,0,13.1,40005.382349537,2009-07-11,09:10:35\n',
#  '31.5848083,120.3190266,0,16.4,40005.3823726852,2009-07-11,09:10:37\n',
#  '31.585075,120.3186116,0,29.5,40005.3824074074,2009-07-11,09:10:40\n',
#  '31.585005,120.3178983,0,3.3,40005.3824884259,2009-07-11,09:10:47\n',
#  '31.5848783,120.3177449,0,0,40005.3825115741,2009-07-11,09:10:49\n',
#  '31.5847666,120.3176233,0,0,40005.3825347222,2009-07-11,09:10:51\n',
#  '31.5846966,120.3175083,0,3.3,40005.3825578704,2009-07-11,09:10:53\n',
#  '31.5846816,120.3174083,0,0,40005.3825810185,2009-07-11,09:10:55\n',
#  '31.5846866,120.3173249,0,0,40005.3826041667,2009-07-11,09:10:57\n',
# ...

# %%
import os
list_ = os.listdir('sorted_data/128/Trajectory/')

import urllib.request, json
import pandas as pd
import os
import sys
import json

# 데이터를 
sorted_128 = []

# client_id = "65xw2v8rw33_NOSdyN3z"
# client_secret = "PJrpJbOVjA"
    
for i in range(len(list_)):
    file_ = open('sorted_data/128/Trajectory/' + list_[i], 'r') 
    file = file_.readlines()
    file = file[6:]
    for j in range(len(file)):
        tmp = file[j].split(',')
        if j % 20 == 0:
            with urllib.request.urlopen("https://maps.googleapis.com/maps/api/geocode/json?latlng=" + tmp[0] + "," + tmp[1] + "&key=AIzaSyClbiBnOUKA_p-VzyF7R7cwdnQ1yHrTtHw&language=ko") as url:
                data = json.loads(url.read().decode())
            address = ''
            for k in range(10):
                try:
                    if len(tmp) < len(data['results'][i]['formatted_address']):
                        address = data['results'][i]['formatted_address']
#                         address = data['results'][i]['formatted_address']
#                         encText = urllib.parse.quote(address)
#                         data = "source=zh-CN&target=ko&text=" + encText
#                         url = "https://openapi.naver.com/v1/papago/n2mt"
#                         request = urllib.request.Request(url)
#                         request.add_header("X-Naver-Client-Id",client_id)
#                         request.add_header("X-Naver-Client-Secret",client_secret)
#                         response = urllib.request.urlopen(request, data=data.encode("utf-8"))
#                         rescode = response.getcode()
#                         if(rescode==200):
#                             response_body = response.read()
#                             result_str = response_body.decode('utf-8') # type가 string이네

#                             result = json.loads(result_str) 
#                             address = result['message']['result']['translatedText']
#                             break
    #                     else:
    #                         print("Error Code:" + rescode)
                except IndexError:
                    pass
            sorted_128.append([tmp[0], tmp[1], tmp[-2], tmp[-1][:-1], address])
        else:
            sorted_128.append([tmp[0], tmp[1], tmp[-2], tmp[-1][:-1], 0])
df = pd.DataFrame(sorted_128)
df.to_csv('sorted_128.csv')
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# <ipython-input-229-5be6c84ec0c3> in <module>
#      18         tmp = file[j].split(',')
#      19         if j % 20 == 0:
# ---> 20             with urllib.request.urlopen("https://maps.googleapis.com/maps/api/geocode/json?latlng=" + tmp[0] + "," + tmp[1] + "&key=AIzaSyClbiBnOUKA_p-VzyF7R7cwdnQ1yHrTtHw&language=ko") as url:
#      21                 data = json.loads(url.read().decode())
#      22             address = ''
#
# ~\anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# ...

# %%
df = pd.DataFrame(sorted_128)
df.to_csv('sorted_128_last.csv')

# %%
df.to_csv('sorted_128.csv')

# %%
df.iloc[60][4]
# Out:
# '중국 Beijing Shi, Haidian Qu, 安宁庄东路北口'

# %%
df2 = pd.read_csv('sorted_128.csv')

# %%
import os
list_ = os.listdir('153/Trajectory/')

import urllib.request, json
import pandas as pd
import os
import sys
import json

# 데이터를 
sorted_128 = []

for i in range(len(list_)):
    file_ = open('sorted_data/128/Trajectory/' + list_[i], 'r') 
    file = file_.readlines()
    file = file[6:]
    for j in range(len(file)):
        tmp = file[j].split(',')
        if j % 20 == 0:
            with urllib.request.urlopen("https://maps.googleapis.com/maps/api/geocode/json?latlng=" + tmp[0] + "," + tmp[1] + "&key=AIzaSyB3n2n5jV922yXCtI3qZC2Xcqb8sPUYPA8&language=ko") as url:
                data = json.loads(url.read().decode())
            address = ''
            for k in range(10):
                try:
                    if len(tmp) < len(data['results'][i]['formatted_address']):
                        address = data['results'][i]['formatted_address']
#                         address = data['results'][i]['formatted_address']
#                         encText = urllib.parse.quote(address)
#                         data = "source=zh-CN&target=ko&text=" + encText
#                         url = "https://openapi.naver.com/v1/papago/n2mt"
#                         request = urllib.request.Request(url)
#                         request.add_header("X-Naver-Client-Id",client_id)
#                         request.add_header("X-Naver-Client-Secret",client_secret)
#                         response = urllib.request.urlopen(request, data=data.encode("utf-8"))
#                         rescode = response.getcode()
#                         if(rescode==200):
#                             response_body = response.read()
#                             result_str = response_body.decode('utf-8') # type가 string이네

#                             result = json.loads(result_str) 
#                             address = result['message']['result']['translatedText']
#                             break
    #                     else:
    #                         print("Error Code:" + rescode)
                except IndexError:
                    pass
            sorted_128.append([tmp[0], tmp[1], tmp[-2], tmp[-1][:-1], address])
        else:
            sorted_128.append([tmp[0], tmp[1], tmp[-2], tmp[-1][:-1], 0])
df = pd.DataFrame(sorted_128)
df.to_csv('sorted_153.csv')

# %%
df[4].unique()
# Out:
# array(['중국 Beijing Shi, Haidian Qu, 부용리남길(만천하초등학교 옆)', '',
#        'Unnamed Road, Haidian Qu, Beijing Shi, 중국',
#        '중국 Beijing Shi, Haidian Qu, 이화원로',
#        '중국 Beijing Shi, Haidian Qu, 초교7번 농업과학연구소 107호',
#        'Fu Rong Nan Jie, Haidian Qu, Beijing Shi, 중국',
#        '중국비이징샤이, 하이디안큐, 중관촌해전교백환아파트 10층',
#        '중국 Beijing Shi, Haidian Qu, 백환지 동80m',
#        '중국 삐이징샤이, 하이디안큐, 서원초장 15호', '중국 삐이징샤이, 하이디안쿠, 하이뎬거리갑 36번 1층',
#        '장 리안 야다 샤 B 주오, 차양규, 비징시, 중국',
#        'Xi Ba He Nan Lu, Chaoyang Qu, Beijing Shi, 중국',
#        '중국 Beijing Shi, Chaoyang Qu, 서제방 하남리', '중국 베일 시차오양구',
#        'Bei Jing Jin Yu Xi Lai Deng Da Jiu Diian, An Ding Men, Dongcheng Qu, Beijing Shi, 중국',
#        'Andingmen, Dongcheng, Beijing, 중국',
#        'Gu Lou Wai Da Jie, An Ding Men, Chaoyang Qu, Beijing Shi, 중국',
#        '2 Bei San Huan Lu, Chaoyang Qu, Beijing Shi, 중국 100035',
#        '23-108 Huang Si Da Jie, Xicheng Qu, Beijing Shi, 중국 100082',
# ...

# %%
for i in range(len(list_)):
    file_ = open('sorted_data/025/Trajectory/' + list_[i], 'r') 
    file = file_.readlines()
    file = file[6:]
    for j in range(len(file)):
        tmp = file[j].split(',')
        if j % 40 == 0:
            with urllib.request.urlopen("https://maps.googleapis.com/maps/api/geocode/json?latlng=" + tmp[0] + "," + tmp[1] + "&key=AIzaSyClbiBnOUKA_p-VzyF7R7cwdnQ1yHrTtHw&language=ko") as url:
                data = json.loads(url.read().decode())
            address = ''
            for k in range(10):
                try:
                    if len(tmp) < len(data['results'][i]['formatted_address']):
                        address = 
#                         address = data['results'][i]['formatted_address']
#                         encText = urllib.parse.quote(address)
#                         data = "source=zh-CN&target=ko&text=" + encText
#                         url = "https://openapi.naver.com/v1/papago/n2mt"
#                         request = urllib.request.Request(url)
#                         request.add_header("X-Naver-Client-Id",client_id)
#                         request.add_header("X-Naver-Client-Secret",client_secret)
#                         response = urllib.request.urlopen(request, data=data.encode("utf-8"))
#                         rescode = response.getcode()
#                         if(rescode==200):
#                             response_body = response.read()
#                             result_str = response_body.decode('utf-8') # type가 string이네

#                             result = json.loads(result_str) 
#                             address = result['message']['result']['translatedText']
#                             break
                        else:
                            print("Error Code:" + rescode)
                except IndexError:
                    pass
            sorted_25.append([tmp[0], tmp[1], tmp[-2], tmp[-1][:-1], address])
        else:
            sorted_25.append([tmp[0], tmp[1], tmp[-2], tmp[-1][:-1], ''])
df = pd.DataFrame(sorted_25)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-190-5360f077cfed> in <module>
#       6         tmp = file[j].split(',')
#       7         if j % 20 == 0:
# ----> 8             with urllib.request.urlopen("https://maps.googleapis.com/maps/api/geocode/json?latlng=" + tmp[0] + "," + tmp[1] + "&key=AIzaSyClbiBnOUKA_p-VzyF7R7cwdnQ1yHrTtHw&language=ko") as url:
#       9                 data = json.loads(url.read().decode())
#      10             address = ''
#
# ~\anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
# ...

# %%
df = pd.DataFrame(sorted_25)

# %%
df.to_csv('sorted_25_2.csv')

# %%
len(df[4].unique())
# Out:
# 63

# %%
df
# Out:
#                  0            1           2         3  \
# 0       39.9865216  116.3028116  2008-12-15  00:01:52
# 1       39.9865216  116.3028049  2008-12-15  00:01:53
# 2       39.9865266  116.3027666  2008-12-15  00:01:56
# 3       39.9865383  116.3026649  2008-12-15  00:01:58
# 4       39.9865083  116.3026616  2008-12-15  00:02:00
# ...            ...          ...         ...       ...
# 221480  39.9826883  116.3089016  2009-03-08  08:11:05
# 221481   39.982665  116.3088766  2009-03-08  08:11:07
# 221482   39.982775  116.3089266  2009-03-08  08:11:09
# 221483  39.9828716  116.3089499  2009-03-08  08:11:11
# 221484  39.9828733  116.3088883  2009-03-08  08:11:13
#
#                                                    4
# 0       중국 Beijing Shi, Haidian Qu, 부용리남길(만천하초등학교 옆)
# 1
# 2
# 3
# 4
# ...                                              ...
# 221480
# 221481
# 221482
# 221483
# 221484
#
# [221485 rows x 5 columns]

# %%
a = '''
{"message":{"@type":"response","@service":"naverservice.nmt.proxy","@version":"1.0.0","result":{"srcLangType":"zh-CN","tarLangType":"ko","translatedText":"중국 Beijing Shi, Haidian Qu, 부용리남길(만천하초등학교 옆)","engineType":"N2MT","pivot":'null'}}}
'''
a
# Out:
# '\n{"message":{"@type":"response","@service":"naverservice.nmt.proxy","@version":"1.0.0","result":{"srcLangType":"zh-CN","tarLangType":"ko","translatedText":"중국 Beijing Shi, Haidian Qu, 부용리남길(만천하초등학교 옆)","engineType":"N2MT","pivot":\'null\'}}}\n'

# %%
a = {"message":{"@type":"response","@service":"naverservice.nmt.proxy","@version":"1.0.0","result":{"srcLangType":"zh-CN","tarLangType":"ko","translatedText":"중국 Beijing Shi, Haidian Qu, 부용리남길(만천하초등학교 옆)","engineType":"N2MT","pivot":'null'}}}
a['message']['result']['translatedText']
# Out:
# '중국 Beijing Shi, Haidian Qu, 부용리남길(만천하초등학교 옆)'

# %%
a = {"message":{"@type":"response","@service":"naverservice.nmt.proxy","@version":"1.0.0","result":{"srcLangType":"zh-CN","tarLangType":"ko","translatedText":"중국 Beijing Shi, Haidian Qu, 부용리남길(만천하초등학교 옆)","engineType":"N2MT","pivot":'null'}}}

# %%
a['message']['result']['translatedText']
# Out:
# '중국 Beijing Shi, Haidian Qu, 부용리남길(만천하초등학교 옆)'

# %%
# 네이버 기계번역 API 예제
import os
import sys
import urllib.request
client_id = "65xw2v8rw33_NOSdyN3z"
client_secret = "PJrpJbOVjA"
encText = urllib.parse.quote("芙蓉里南街（万泉河小学旁）")
data = "source=zh-CN&target=ko&text=" + encText
url = url = "https://openapi.naver.com/v1/papago/n2mt"
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request, data=data.encode("utf-8"))
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {"message":{"@type":"response","@service":"naverservice.nmt.proxy","@version":"1.0.0","result":{"srcLangType":"zh-CN","tarLangType":"ko","translatedText":"부용리남길(만천하초등학교 옆)","engineType":"N2MT","pivot":null}}}

# %%
import pandas as pd
pd.DataFrame(sorted_25)
#df = np.array(sorted_25)
# Out:
#                0            1           2        3  \
# 0     39.9865216  116.3028116  2008-12-15  00:01:5
# 1     39.9865216  116.3028049  2008-12-15  00:01:5
# 2     39.9865266  116.3027666  2008-12-15  00:01:5
# 3     39.9865383  116.3026649  2008-12-15  00:01:5
# 4     39.9865083  116.3026616  2008-12-15  00:02:0
# ...          ...          ...         ...      ...
# 1485  39.9552316  116.4525433  2008-12-16  01:05:5
# 1486  39.9552299   116.452605  2008-12-16  01:05:5
# 1487   39.955225    116.45266  2008-12-16  01:06:0
# 1488  39.9552216  116.4527016  2008-12-16  01:06:0
# 1489  39.9552283  116.4527416  2008-12-16  01:06:0
#
#                                               4
# 0     중국 Beijing Shi, Haidian Qu, 芙蓉里南街（万泉河小学旁）
# 1
# 2
# 3
# 4
# ...                                         ...
# 1485
# 1486                              중국 베이징 시 차오양구
# 1487
# 1488
# 1489
#
# [1490 rows x 5 columns]

# %%
list_
# Out:
# ['Geolife trajectory\n',
#  'WGS 84\n',
#  'Altitude is in Feet\n',
#  'Reserved 3\n',
#  '0,2,255,My Track,0,0,2,8421376\n',
#  '0\n',
#  '39.9632716,116.4377583,0,229.7,39798.2328125,2008-12-16,05:35:15\n',
#  '39.96335,116.4376533,0,229.7,39798.2328240741,2008-12-16,05:35:16\n',
#  '39.9635716,116.4373516,0,229.7,39798.2328587963,2008-12-16,05:35:19\n',
#  '39.9637016,116.4371683,0,229.7,39798.2328819444,2008-12-16,05:35:21\n',
#  '39.963815,116.4370099,0,229.7,39798.2329050926,2008-12-16,05:35:23\n',
#  '39.9639116,116.4368916,0,229.7,39798.2329282407,2008-12-16,05:35:25\n',
#  '39.9639666,116.436805,0,229.7,39798.2329513889,2008-12-16,05:35:27\n',
#  '39.9639716,116.4367599,0,229.7,39798.232974537,2008-12-16,05:35:29\n',
#  '39.9639499,116.4367433,0,229.7,39798.2331828704,2008-12-16,05:35:47\n',
#  '39.9639749,116.4367066,0,229.7,39798.2332060185,2008-12-16,05:35:49\n',
#  '39.9640133,116.4366466,0,229.7,39798.2332291667,2008-12-16,05:35:51\n',
# ...

# %%
list_ = os.listdir('sorted_data/025/Trajectory/')

# %%
list_
# Out:
# ['20081215000152.plt',
#  '20081215104440.plt',
#  '20081215113016.plt',
#  '20081216010001.plt',
#  '20081216010234.plt',
#  '20081216053515.plt',
#  '20081216060748.plt',
#  '20081216075439.plt',
#  '20081216080524.plt',
#  '20081216111246.plt',
#  '20081216120743.plt',
#  '20081217010000.plt',
#  '20081217014427.plt',
#  '20081217103050.plt',
#  '20081217111420.plt',
#  '20081217112440.plt',
#  '20081217123427.plt',
#  '20081219010000.plt',
#  '20081219013700.plt',
#  '20081219015021.plt',
#  '20081219021315.plt',
#  '20081219024801.plt',
#  '20081219031120.plt',
#  '20081219045409.plt',
#  '20081219071549.plt',
#  '20081219074250.plt',
#  '20081219090103.plt',
#  '20081219125012.plt',
#  '20081220001017.plt',
#  '20081220014325.plt',
#  '20081221012534.plt',
#  '20081221032318.plt',
#  '20081221041154.plt',
#  '20081221042218.plt',
#  '20081221044222.plt',
#  '20081221055902.plt',
#  '20081221070930.plt',
#  '20081221071543.plt',
#  '20081221083128.plt',
#  '20081222013746.plt',
# ...

# %%
new = []

for i in range():
    file = file1.readlines() 
    for i in range(6,len(file)):
        new.append([file[i].split(',')[0], file[i].split(',')[1],  file[i].split(',')[5],  file[i].split(',')[6][:-1]])

# %%
len(new)
# Out:
# 682

# %%
# 1. 해외의 좌표들을 가지고 와서 크롤링을 해볼 생각이었는데, 잘안된다는 점
# 2. 시도했던 방식

# %%
# !pip install selenium

# %%
from selenium import webdriver
driver = webdriver.Chrome()

# %%
# open map 시도

# %%
driver.get('https://www.openstreetmap.org/#map=12/39.9866/116.3028')
import time
time.sleep(0.5)
element = driver.find_element_by_class_name('describe_location')
element.send_keys("39.9865216 116.3028116")
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# <ipython-input-100-1c09cc99555c> in <module>
#       3 time.sleep(0.5)
#       4 element = driver.find_element_by_class_name('describe_location')
# ----> 5 element.send_keys("39.9865216 116.3028116")
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in send_keys(self, *value)
#     477         self._execute(Command.SEND_KEYS_TO_ELEMENT,
#     478                       {'text': "".join(keys_to_typing(value)),
# --> 479                        'value': keys_to_typing(value)})
#     480
#     481     # RenderedWebElement Items
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
# ...

# %%
https://maps.googleapis.com/maps/api/geocode/outputFormat?parameters

# %%
import time
time.sleep(0.5)
element = driver.find_element_by_class_name('search_form')
element.send_keys("39.9865216 116.3028116")
#element.click('//*[@id="sidebar"]/div[1]/form[1]/input')
# Out:
# ---------------------------------------------------------------------------
# ElementNotInteractableException           Traceback (most recent call last)
# <ipython-input-97-fe0bcfbdb1e7> in <module>
#       2 time.sleep(0.5)
#       3 element = driver.find_element_by_class_name('search_form')
# ----> 4 element.send_keys("39.9865216 116.3028116")
#       5 #element.click('//*[@id="sidebar"]/div[1]/form[1]/input')
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in send_keys(self, *value)
#     477         self._execute(Command.SEND_KEYS_TO_ELEMENT,
#     478                       {'text': "".join(keys_to_typing(value)),
# --> 479                        'value': keys_to_typing(value)})
#     480
#     481     # RenderedWebElement Items
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# ...

# %%
driver.get('https://www.google.com/webhp?hl=ko&ictx=2&sa=X&ved=0ahUKEwjG46je39ntAhVUa94KHaYTD5cQPQgI')

# %%
element.click('//*[@id="sidebar"]/div[1]/form[1]/input')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-96-a92a264bb346> in <module>
# ----> 1 element.click('//*[@id="sidebar"]/div[1]/form[1]/input')
#
# TypeError: click() takes 1 positional argument but 2 were given

# %%
import time
time.sleep(0.5)
element = driver.find_element_by_name('q')
element.send_keys("39.9865216 116.3028116")
element.click('//*[@id="sidebar"]/div[1]/form[1]/input')

# %%
element
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="dfa3dd588f15154ffa9dbb57a8f91396", element="55ec44c1-7514-4cfe-93c1-1f0b8433e31b")>

# %%
//*[@id="sidebar"]/div[1]/form[1]/input

# %%
driver.find_elements_by_xpath('//*[@id="searchbox"]')
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="dfa3dd588f15154ffa9dbb57a8f91396", element="8688168a-adde-427c-922b-3dbf9219c771")>]

# %%
submit_button = driver.find_elements_by_xpath('//*[@id="searchbox"]')[0]
submit_button.click()

# %%
# 구글 맵 시도

# %%
driver.get('https://www.google.com/webhp?hl=ko&ictx=2&sa=X&ved=0ahUKEwjG46je39ntAhVUa94KHaYTD5cQPQgI')
element = driver.find_element_by_name('q')
element.send_keys("39.9865216 116.3028116")
element.click()

# %%
element.submit()

# %%
driver.find_element_by_class_name('searchbox-searchbutton')
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="dfa3dd588f15154ffa9dbb57a8f91396", element="cca28421-6d8b-44d7-9690-3fdb6d69e2a9")>

# %%
from selenium import webdriver
driver = webdriver.Chrome()
#driver.get('https://www.google.co.kr/maps/@37.053745,125.6553969,5z?hl=ko')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\selenium\webdriver\common\service.py in start(self)
#      75                                             stderr=self.log_file,
# ---> 76                                             stdin=PIPE)
#      77         except TypeError:
#
# ~\anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     799                                 errread, errwrite,
# --> 800                                 restore_signals, start_new_session)
#     801         except:
#
# ...

# %%
# 구글 api를 활용해서 정보를 가져오기로 함

# %%
AIzaSyB1zmmpk_xQA28GhvGa4uDW6n6eIbWzscE

# %%
'https://maps.googleapis.com/maps/api/geocode/json?latlng='++','++&key=AIzaSyClbiBnOUKA_p-VzyF7R7cwdnQ1yHrTtHw'

# %%
'39.9632716', '116.4377583'

# %%
https://maps.googleapis.com/maps/api/geocode/json?latlng=39.9632716,116.4377583&key=AIzaSyClbiBnOUKA_p-VzyF7R7cwdnQ1yHrTtHw&language=ko

# %%
https://maps.googleapis.com/maps/api/geocode/json?latlng=37.6489286,127.0834112&key=AIzaSyClbiBnOUKA_p-VzyF7R7cwdnQ1yHrTtHw&language=ko

# %%
import urllib, json

url = "https://maps.googleapis.com/maps/api/geocode/json?latlng=37.6489286,127.0834112&key=AIzaSyClbiBnOUKA_p-VzyF7R7cwdnQ1yHrTtHw&language=ko"

response = urllib.response(url)

data = json.loads(response.read())
print(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-102-a80d9ee83cba> in <module>
#       3 url = "https://maps.googleapis.com/maps/api/geocode/json?latlng=37.6489286,127.0834112&key=AIzaSyClbiBnOUKA_p-VzyF7R7cwdnQ1yHrTtHw&language=ko"
#       4
# ----> 5 response = urllib.response(url)
#       6
#       7 data = json.loads(response.read())
#
# TypeError: 'module' object is not callable

# %%
'39.9632716', '116.4377583'

# %%
import urllib.request, json 
with urllib.request.urlopen("https://maps.googleapis.com/maps/api/geocode/json?latlng=39.9632716,116.4377583&key=AIzaSyClbiBnOUKA_p-VzyF7R7cwdnQ1yHrTtHw&language=ko") as url:
    data = json.loads(url.read().decode())
for i in range(10):
    print(data['results'][i]['formatted_address']) #['address_components']#['formatted_address']

# %%
for i in range(10):
    print(data['results'][i]['formatted_address']) #['address_components']#['formatted_address']
# Out:
# Tian Zhi Xing Jiu Dian, Chaoyang Qu, Beijing Shi, 중국
# Xi Ba He Nan Lu, Chaoyang Qu, Beijing Shi, 중국
# 중국 베이징 시 차오양구
# 중국 베이징 시 베이징시
# 중국 베이징 시
# 중국
# XC7Q+84 중국 베이징 시 차오양구
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-128-189a01adde69> in <module>
#       1 for i in range(10):
# ----> 2     print(data['results'][i]['formatted_address']) #['address_components']#['formatted_address']
#
# IndexError: list index out of range

# %%
# 성민 코드

# %%
import os
list_ = os.listdir('sorted_data/128/Trajectory/')

# %%
list_ = sorted(list_)

# %%
list_
# Out:
# ['20070414005628.plt',
#  '20070414123327.plt',
#  '20070414234445.plt',
#  '20070416131735.plt',
#  '20070418115239.plt',
#  '20070419015158.plt',
#  '20070419131605.plt',
#  '20070420005635.plt',
#  '20070420145301.plt',
#  '20070421005720.plt',
#  '20070421005859.plt',
#  '20070422095150.plt',
#  '20070430125130.plt',
#  '20070504235730.plt',
#  '20070506033305.plt',
#  '20070508010354.plt',
#  '20070524014129.plt',
#  '20070527004831.plt',
#  '20070528130243.plt',
#  '20070529010201.plt',
#  '20070529141743.plt',
#  '20070530011315.plt',
#  '20070530114100.plt',
#  '20070531005841.plt',
#  '20070531131532.plt',
#  '20070531235335.plt',
#  '20070601144505.plt',
#  '20070603071435.plt',
#  '20070604010322.plt',
#  '20070604123610.plt',
#  '20070605011440.plt',
#  '20070606011909.plt',
#  '20070606124955.plt',
#  '20070607005351.plt',
#  '20070607133450.plt',
#  '20070608011322.plt',
#  '20070608145746.plt',
#  '20070611012257.plt',
#  '20070620130412.plt',
#  '20070621011147.plt',
# ...

# %%
len(list_)
# Out:
# 809

# %%
sorted(list_)

# %%
list_ = os.listdir('sorted_data/128/Trajectory/')
list_ = sorted(list_)

# %%
list_[:100]
# Out:
# ['20070414005628.plt',
#  '20070414123327.plt',
#  '20070414234445.plt',
#  '20070416131735.plt',
#  '20070418115239.plt',
#  '20070419015158.plt',
#  '20070419131605.plt',
#  '20070420005635.plt',
#  '20070420145301.plt',
#  '20070421005720.plt',
#  '20070421005859.plt',
#  '20070422095150.plt',
#  '20070430125130.plt',
#  '20070504235730.plt',
#  '20070506033305.plt',
#  '20070508010354.plt',
#  '20070524014129.plt',
#  '20070527004831.plt',
#  '20070528130243.plt',
#  '20070529010201.plt',
#  '20070529141743.plt',
#  '20070530011315.plt',
#  '20070530114100.plt',
#  '20070531005841.plt',
#  '20070531131532.plt',
#  '20070531235335.plt',
#  '20070601144505.plt',
#  '20070603071435.plt',
#  '20070604010322.plt',
#  '20070604123610.plt',
#  '20070605011440.plt',
#  '20070606011909.plt',
#  '20070606124955.plt',
#  '20070607005351.plt',
#  '20070607133450.plt',
#  '20070608011322.plt',
#  '20070608145746.plt',
#  '20070611012257.plt',
#  '20070620130412.plt',
#  '20070621011147.plt',
# ...

# %%
import os

import urllib.request, json
import pandas as pd
import os
import sys
import json
list_ = os.listdir('sorted_data/128/Trajectory/')
list_ = sorted(list_)

# 데이터를 
sorted_128 = []
list_ = sorted(list_)
for i in range(100):#len(list_)):
    file_ = open('sorted_data/128/Trajectory/' + list_[i], 'r') 
    file = file_.readlines()
    file = file[6:]
    for j in range(len(file)):
        tmp = file[j].split(',')
        if j % 30 == 0:
            with urllib.request.urlopen("https://maps.googleapis.com/maps/api/geocode/json?latlng=" + tmp[0] + "," + tmp[1] + "&key=AIzaSyClbiBnOUKA_p-VzyF7R7cwdnQ1yHrTtHw&language=ko") as url:
                data = json.loads(url.read().decode())
            address = ''
            for k in range(10):
                try:
                    if len(address) < len(data['results'][k]['formatted_address']):
                        address = data['results'][k]['formatted_address']
#                         address = data['results'][i]['formatted_address']
#                         encText = urllib.parse.quote(address)
#                         data = "source=zh-CN&target=ko&text=" + encText
#                         url = "https://openapi.naver.com/v1/papago/n2mt"
#                         request = urllib.request.Request(url)
#                         request.add_header("X-Naver-Client-Id",client_id)
#                         request.add_header("X-Naver-Client-Secret",client_secret)
#                         response = urllib.request.urlopen(request, data=data.encode("utf-8"))
#                         rescode = response.getcode()
#                         if(rescode==200):
#                             response_body = response.read()
#                             result_str = response_body.decode('utf-8') # type가 string이네

#                             result = json.loads(result_str) 
#                             address = result['message']['result']['translatedText']
#                             break
    #                     else:
    #                         print("Error Code:" + rescode)
                except IndexError:
                    pass
            sorted_128.append([tmp[0], tmp[1], tmp[-2], tmp[-1][:-1], address])
        else:
            sorted_128.append([tmp[0], tmp[1], tmp[-2], tmp[-1][:-1], 0])
df = pd.DataFrame(sorted_128)
df.to_csv('sorted_128_100.csv')

# %%
df2 = df.sort_values(by=2)

# %%
df2[2].unique()
# Out:
# array(['2000-01-01', '2007-04-12', '2007-04-13', '2007-04-16',
#        '2007-05-18', '2007-05-19', '2007-05-20', '2007-05-21',
#        '2007-06-11', '2007-06-12', '2007-06-13', '2007-06-14',
#        '2007-06-15', '2007-06-16', '2007-06-17', '2007-06-18',
#        '2007-06-19', '2007-06-20', '2007-07-10', '2007-07-11',
#        '2007-07-13', '2007-07-14', '2007-07-15', '2007-07-16',
#        '2007-07-17', '2007-07-18', '2007-07-19', '2007-07-20',
#        '2007-07-31', '2007-10-09', '2007-10-10', '2007-10-12',
#        '2007-10-13', '2007-10-15', '2007-10-16', '2007-10-17',
#        '2007-10-19', '2007-10-20', '2007-10-21', '2007-10-22',
#        '2007-10-23', '2007-10-24', '2007-10-25', '2007-10-26',
#        '2007-10-27', '2007-10-28', '2007-10-29', '2007-11-22',
#        '2007-11-23', '2007-11-24', '2007-11-25', '2007-11-26',
#        '2007-11-27', '2007-11-28', '2007-11-29', '2007-12-01',
#        '2008-04-03', '2008-04-04', '2008-04-05', '2008-04-06',
# ...

# %%
tmp =[str(39.975005), str(116.344832)]

with urllib.request.urlopen("https://maps.googleapis.com/maps/api/geocode/json?latlng=" + tmp[0] + "," + tmp[1] + "&key=AIzaSyCX7jhTMi-Y4r8c5HT4EGBnaqBo66WaXnQ&language=ko") as url:
    data = json.loads(url.read().decode())

# %%
data['results'][0]['formatted_address']
# Out:
# 'Tian Yi Hu Lian Wang Shou Ji Mai Chang ( Luo Zhuang Zhong Lu ), Haidian Qu, Beijing Shi, 중국'
